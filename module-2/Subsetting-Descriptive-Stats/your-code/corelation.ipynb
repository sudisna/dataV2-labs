# %%
#import libraries
import numpy as np
import pandas as pd
#import files
disaster = pd.read_csv('CDD.csv',sep = '\t')
disaster.head()
# Out:
#   EVENT CATEGORY EVENT GROUP                 EVENT SUBGROUP  \
# 0       Disaster     Natural  Meteorological - Hydrological
# 1       Disaster     Natural  Meteorological - Hydrological
# 2       Disaster     Natural  Meteorological - Hydrological
# 3       Disaster     Natural                     Biological
# 4       Incident  Technology            Hazardous Chemicals
#
#                     EVENT TYPE                                 PLACE  \
# 0  Storm - Unspecified / Other                   Christmas Island NS
# 1                 Winter Storm  Nova Scotia and Prince Edward Island
# 2                        Flood             Red Earth First Nation SK
# 3                     Epidemic              Alberta and Saskatchewan
# 4         Leak / Spill Release                   Seaforth Channel BC
#
#          EVENT START DATE                                           COMMENTS  \
# 0  25/12/2016 12:00:00 AM  Christmas Island NS, December 25, 2016. Reside...
# ...

# %%
#printthe correlation matrix
disaster.corr()
# Out:
#                                 FATALITIES  INJURED / INFECTED  EVACUATED  \
# FATALITIES                        1.000000            0.998728  -0.003530
# INJURED / INFECTED                0.998728            1.000000  -0.003554
# EVACUATED                        -0.003530           -0.003554   1.000000
# ESTIMATED TOTAL COST              0.027839            0.073538   0.660335
# NORMALIZED TOTAL COST             0.031352            0.080907   0.580352
# FEDERAL DFAA PAYMENTS             0.014838            0.311491   0.406679
# PROVINCIAL DFAA PAYMENTS         -0.020317            0.404215   0.083692
# PROVINCIAL DEPARTMENT PAYMENTS   -0.023630           -0.002056   0.212975
# MUNICIPAL COSTS                   0.965880            0.965286   0.514186
# OGD COSTS                         0.417442           -0.036915   0.154761
# INSURANCE PAYMENTS                0.241347            0.456924   0.825937
# NGO PAYMENTS                      0.966678            0.999639   0.838898
# ...

# %%
#create a heat map
#simple
disaster.corr().style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\sudis\anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_72dc3428_a0e4_11ea_9ec2_dc8b28b5ce2frow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_72dc3428_a0e4_11ea_9ec2_dc8b28b5ce2frow0_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_72dc3428_a0e4_11ea_9ec2_dc8b28b5ce2frow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72dc3428_a0e4_11ea_9ec2_dc8b28b5ce2frow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72dc3428_a0e4_11ea_9ec2_dc8b28b5ce2frow0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_72dc3428_a0e4_11ea_9ec2_dc8b28b5ce2frow0_col5 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
# ...

# %%
#create a heat map
# more visually appealing
import seaborn as sns
# %matplotlib inline
sns.heatmap(disaster.corr())

# %%
"""
Find 3 pairs of columns, one pair that is highly positively correlated, one for which the correlation is almost zero
and one pair that is negatively correlated. In each case write down an explanation why we see this correlation

Highly correlated : [MUNICIPAL COSTS, NGO PAYMENTS]:0.999999 as well as [UTILITY - PEOPLE AFFECTED, NGO PAYMENTS]
Reason: If there is loss to utility then it can be solved by the payments made by NGO.
Correlation is zero: [UTILITY - PEOPLE AFFECTED,INJURED / INFECTED]:-0.001498
Reason: If there is loss to utility then it does not necessarily mean that people will be affected
Negatively Correlated : [UTILITY - PEOPLE AFFECTED,OGD COSTS]:0.092983
Reason: If there is loss to utility then it does not affect the cost made by other government departments 
it should be carried out by NGOs or municipality.
"""
# Out:
# (14.0, 0.0)

# %%
"""
Look up the pairplot function in Seaborn. Use it to plot the pairwise relations between the six columns you selected. 
Does what you see confirm your ideas? Describe in a comment.

"""

g = sns.pairplot(disaster, vars=["UTILITY - PEOPLE AFFECTED", "NGO PAYMENTS"])

# %%
g = sns.pairplot(disaster, vars=["UTILITY - PEOPLE AFFECTED","INJURED / INFECTED"])

# %%
g = sns.pairplot(disaster, vars=["UTILITY - PEOPLE AFFECTED","OGD COSTS"])
